# %%
import pandas as pd
import glob
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
# dữ liệu nội trú
file_list = glob.glob(r'D:\SOLIEU\SOLIEUPHANTICH\SOSANH\NOITRU\*.xlsx')
files = []

# %%
for filename in file_list:
    df = pd.concat(pd.read_excel(filename, sheet_name=None), ignore_index=True)
    files.append(df)
frame_noitru = pd.concat(files, axis=0, ignore_index=True)

# %%
#frame.select_dtypes(include='int64')
#frame.isna().sum()
#frame.describe()
#table = pd.pivot_table(frame,index=['MA_CSKCB'],columns=['THANG_QT'],values=['T_BHTT'],aggfunc=['sum'])
tablecount = frame_noitru[["MA_CSKCB","THANG_QT"]].copy()

# %%
#frame

# %%
sns.set_theme(style="darkgrid")
ax = plt.subplots(figsize = (10,5))
plt.title('Số lượt tăng giảm')
ax = sns.countplot(x="MA_CSKCB", hue="THANG_QT", data=tablecount)

# %%
tablesum = frame_noitru[["MA_CSKCB","THANG_QT","T_XN","T_CDHA","T_VTYT","T_THUOC","T_MAU","T_PTTT","T_KHAM","T_GIUONG","T_BHTT"]].copy()
ax = plt.subplots(figsize = (10,5))
ax = sns.barplot(x = "MA_CSKCB",y = "T_BHTT" ,hue="THANG_QT", data = tablesum,estimator=sum)
plt.title('chi phí tăng giảm')
plt.show()

# %%
# dữ liệu nội trú
file_list = glob.glob(r'D:\SOLIEU\SOLIEUPHANTICH\SOSANH\NGOAITRU\*.xlsx')
files = []

# %%
for filename in file_list:
    df = pd.concat(pd.read_excel(filename, sheet_name=None), ignore_index=True)
    files.append(df)
frame = pd.concat(files, axis=0, ignore_index=True)

# %%
frame.loc[frame['MA_CSKCB'] == 93001, 'MA_CHA'] = '93001'
frame.loc[(frame['MA_CSKCB'] == 93002) | (frame['MA_CSKCB'] == 93048) | (frame['MA_CSKCB'] == 93049) | (frame['MA_CSKCB'] == 93050) | (frame['MA_CSKCB'] == 93051) | (frame['MA_CSKCB'] == 93052)| (frame['MA_CSKCB'] == 93053) | (frame['MA_CSKCB'] == 93054) | (frame['MA_CSKCB'] == 93055) | (frame['MA_CSKCB'] == 93057)  | (frame['MA_CSKCB'] == 93080), 'MA_CHA'] = '93002'
frame.loc[(frame['MA_CSKCB'] == 93003) | (frame['MA_CSKCB'] == 93019) | (frame['MA_CSKCB'] == 93058) | (frame['MA_CSKCB'] == 93059) | (frame['MA_CSKCB'] == 93060) | (frame['MA_CSKCB'] == 93061)| (frame['MA_CSKCB'] == 93092) | (frame['MA_CSKCB'] == 93094) | (frame['MA_CSKCB'] == 93097)  | (frame['MA_CSKCB'] == 93104), 'MA_CHA'] = '93003'
frame.loc[(frame['MA_CSKCB'] == 93004) | (frame['MA_CSKCB'] == 93035) | (frame['MA_CSKCB'] == 93036) | (frame['MA_CSKCB'] == 93037) | (frame['MA_CSKCB'] == 93038) | (frame['MA_CSKCB'] == 93039)| (frame['MA_CSKCB'] == 93040) | (frame['MA_CSKCB'] == 93041) | (frame['MA_CSKCB'] == 93042)  | (frame['MA_CSKCB'] == 93043) | (frame['MA_CSKCB'] == 93044) | (frame['MA_CSKCB'] == 93045) | (frame['MA_CSKCB'] == 93046) | (frame['MA_CSKCB'] == 93047) | (frame['MA_CSKCB'] == 93089) | (frame['MA_CSKCB'] == 93090), 'MA_CHA'] = '93004'
frame.loc[(frame['MA_CSKCB'] == 93005) | (frame['MA_CSKCB'] == 93026) | (frame['MA_CSKCB'] == 93027) | (frame['MA_CSKCB'] == 93028) | (frame['MA_CSKCB'] == 93029) | (frame['MA_CSKCB'] == 93030)| (frame['MA_CSKCB'] == 93031) | (frame['MA_CSKCB'] == 93032) | (frame['MA_CSKCB'] == 93033)  | (frame['MA_CSKCB'] == 93087), 'MA_CHA'] = '93005'
frame.loc[(frame['MA_CSKCB'] == 93006) | (frame['MA_CSKCB'] == 93018) | (frame['MA_CSKCB'] == 93020) | (frame['MA_CSKCB'] == 93022) | (frame['MA_CSKCB'] == 93023) | (frame['MA_CSKCB'] == 93024)| (frame['MA_CSKCB'] == 93025) | (frame['MA_CSKCB'] == 93073) | (frame['MA_CSKCB'] == 93083)  | (frame['MA_CSKCB'] == 93084) | (frame['MA_CSKCB'] == 93086), 'MA_CHA'] = '93006'
frame.loc[(frame['MA_CSKCB'] == 93109) | (frame['MA_CSKCB'] == 93009) | (frame['MA_CSKCB'] == 93010) | (frame['MA_CSKCB'] == 93011) | (frame['MA_CSKCB'] == 93012) | (frame['MA_CSKCB'] == 93013)| (frame['MA_CSKCB'] == 93014) | (frame['MA_CSKCB'] == 93015) | (frame['MA_CSKCB'] == 93017)  | (frame['MA_CSKCB'] == 93082), 'MA_CHA'] = '93109'
frame.loc[(frame['MA_CSKCB'] == 93016) | (frame['MA_CSKCB'] == 93067) | (frame['MA_CSKCB'] == 93068) | (frame['MA_CSKCB'] == 93069) | (frame['MA_CSKCB'] == 93070) | (frame['MA_CSKCB'] == 93071)| (frame['MA_CSKCB'] == 93072), 'MA_CHA'] = '93016'
frame.loc[(frame['MA_CSKCB'] == 93078) | (frame['MA_CSKCB'] == 93062) | (frame['MA_CSKCB'] == 93063) | (frame['MA_CSKCB'] == 93064) | (frame['MA_CSKCB'] == 93065) | (frame['MA_CSKCB'] == 93066)| (frame['MA_CSKCB'] == 93095)| (frame['MA_CSKCB'] == 93096)| (frame['MA_CSKCB'] == 93098), 'MA_CHA'] = '93078'
frame.loc[frame['MA_CSKCB'] == 93007, 'MA_CHA'] = '93007'
frame.loc[frame['MA_CSKCB'] == 93008, 'MA_CHA'] = '93008'
frame.loc[frame['MA_CSKCB'] == 93100, 'MA_CHA'] = '93100'
frame.loc[frame['MA_CSKCB'] == 93101, 'MA_CHA'] = '93101'
frame.loc[frame['MA_CSKCB'] == 93102, 'MA_CHA'] = '93102'
frame.loc[frame['MA_CSKCB'] == 93103, 'MA_CHA'] = '93103'
frame.loc[frame['MA_CSKCB'] == 93105, 'MA_CHA'] = '93105'
frame.loc[frame['MA_CSKCB'] == 93106, 'MA_CHA'] = '93106'
frame.loc[frame['MA_CSKCB'] == 93107, 'MA_CHA'] = '93107'
frame.loc[frame['MA_CSKCB'] == 93110, 'MA_CHA'] = '93110'

# %%
#frame.select_dtypes(include='int64')
#frame.isna().sum()
#frame.describe()
tablecount = frame[["MA_CHA","THANG_QT"]].copy()

# %%
sns.set_theme(style="darkgrid")
ax = plt.subplots(figsize = (10,5))
plt.title('Số lượt tăng giảm')
ax = sns.countplot(x="MA_CHA", hue="THANG_QT", data=tablecount)

# %%
tablesum = frame[["MA_CHA","THANG_QT","T_XN","T_CDHA","T_VTYT","T_THUOC","T_MAU","T_PTTT","T_KHAM","T_GIUONG","T_BHTT"]].copy()
ax = plt.subplots(figsize = (10,5))
ax = sns.barplot(x = "MA_CHA",y = "T_BHTT" ,hue="THANG_QT", data = tablesum,estimator=sum)
plt.title('chi phí tăng giảm')
plt.show()

# %%
files = [frame_noitru,frame]

# %%
so_luot = pd.concat(files, axis=0, ignore_index=True)

# %%
tong_luot = so_luot[["MA_CSKCB","THANG_QT", "MA_THE"]].groupby(["MA_CSKCB","THANG_QT"]).agg({'MA_THE':'count'})

# %%
so_luot_noi_tru = pd.concat(files, axis=0, ignore_index=True)

# %%
so_luot_noi_tru = so_luot_noi_tru[(so_luot_noi_tru['MA_LOAIKCB'] == 3)]
tong_luot_noi_tru = so_luot_noi_tru[["MA_CSKCB","THANG_QT", "MA_THE"]].groupby(["MA_CSKCB","THANG_QT"]).agg({'MA_THE':'count'})

# %%
result = pd.merge(tong_luot, tong_luot_noi_tru,  how='left', left_on=['MA_CSKCB','THANG_QT'], right_on = ['MA_CSKCB','THANG_QT'])

# %%
result = result.replace(np.nan, 0)

# %%
result["Ty_le"] = (result["MA_THE_y"] / result["MA_THE_x"])

# %%
tablengaybq = frame_noitru[["MA_CSKCB","THANG_QT","SO_NGAY_DTRI"]].copy()
ngay_dtri_bq = tablengaybq[["MA_CSKCB","THANG_QT", "SO_NGAY_DTRI"]].groupby(["MA_CSKCB","THANG_QT"]).agg({'SO_NGAY_DTRI':'sum'})
# Out:
#                    SO_NGAY_DTRI
# MA_CSKCB THANG_QT
# 93001    7                 7628
#          8                 7367
# 93002    7                 1942
#          8                   10
# 93003    7                 3454
#          8                 1680
# 93004    7                 1725
#          8                 1246
# 93005    7                 1592
#          8                 1093
# 93006    7                 1951
#          8                  716
# 93007    7                 2250
#          8                 2286
# 93008    7                  304
#          8                  124
# 93016    7                 3993
#          8                 3959
# 93078    7                  592
#          8                  514
# 93100    7                  216
# 93102    7                  637
#          8                  829
# 93103    7                  195
#          8                  161

# %%
total_result = pd.merge(result, ngay_dtri_bq,  how='left', left_on=['MA_CSKCB','THANG_QT'], right_on = ['MA_CSKCB','THANG_QT'])

# %%
result = result.replace(np.nan, 0)
total_result["Ngay_dtri_bq"] = (total_result["SO_NGAY_DTRI"] / total_result["MA_THE_y"])

# %%
total_result.to_excel(r'D:\SOLIEU\SOLIEUPHANTICH\SOSANH\PHANTICHSOLIEUHANGTHANG.xlsx')

# %% [markdown]
# # Dữ liệu tháng - quý hiện tại

# %%
files = []
# dữ liệu nội trú
file_list = glob.glob(r'D:\SOLIEU\SOLIEUPHANTICH\SOSANH\CURRENT\*.xlsx')

# %%
for filename in file_list:
    df = pd.concat(pd.read_excel(filename, sheet_name=None), ignore_index=True)
    files.append(df)
frame_current = pd.concat(files, axis=0, ignore_index=True)

# %%
#frame_current.loc[(frame_current['MA_LOAIKCB'] == 1) | (frame_current['MA_LOAIKCB'] == 2), 'LOAIKCB'] = 'Ngoại trú'
frame_current.loc[(frame_current['MA_LOAIKCB'] == 1), 'LOAIKCB'] = 'Ngoại trú'
frame_current.loc[(frame_current['MA_LOAIKCB'] == 2), 'LOAIKCB'] = 'Điều trị Ngoại trú'
frame_current.loc[frame_current['MA_LOAIKCB'] == 3 , 'LOAIKCB'] = 'Nội trú'

# %%
current = frame_current[["MA_CSKCB","LOAIKCB", "MA_THE","SO_NGAY_DTRI","T_TONGCHI","T_BHTT"]].groupby(["MA_CSKCB","LOAIKCB"]).agg({'MA_THE':'count','SO_NGAY_DTRI':'sum','T_TONGCHI':'sum','T_BHTT':'sum'})

# %%
current['NGAY_DTRI_BQ'] = current["SO_NGAY_DTRI"] / current["MA_THE"]
current['CHIPHI_BQ'] = current["T_TONGCHI"] / current["MA_THE"]

# %%
current.head()
# Out:
#                              MA_THE  SO_NGAY_DTRI     T_TONGCHI        T_BHTT  \
# MA_CSKCB LOAIKCB
# 93001    Ngoại trú             2596             0  6.675080e+08  6.247583e+08
#          Nội trú                894          7367  4.264470e+09  3.768371e+09
#          Điều trị Ngoại trú     109          2766  7.702604e+08  7.597150e+08
# 93002    Ngoại trú             2589             0  2.497088e+08  2.478508e+08
#          Nội trú                  1            10  1.363000e+05  1.363000e+05
#
#                              NGAY_DTRI_BQ     CHIPHI_BQ
# MA_CSKCB LOAIKCB
# 93001    Ngoại trú               0.000000  2.571294e+05
#          Nội trú                 8.240492  4.770101e+06
#          Điều trị Ngoại trú     25.376147  7.066609e+06
# 93002    Ngoại trú               0.000000  9.644991e+04
#          Nội trú                10.000000  1.363000e+05

# %% [markdown]
# # Dữ liệu tháng - quý trước đó

# %%
files = []
# dữ liệu nội trú
file_list = glob.glob(r'D:\SOLIEU\SOLIEUPHANTICH\SOSANH\BEFORE\*.xlsx')

# %%
for filename in file_list:
    df = pd.concat(pd.read_excel(filename, sheet_name=None), ignore_index=True)
    files.append(df)
frame_before = pd.concat(files, axis=0, ignore_index=True)

# %%
frame_before.loc[(frame_before['MA_LOAIKCB'] == 1), 'LOAIKCB'] = 'Ngoại trú'
frame_before.loc[(frame_before['MA_LOAIKCB'] == 2), 'LOAIKCB'] = 'Điều trị Ngoại trú'
frame_before.loc[frame_before['MA_LOAIKCB'] == 3 , 'LOAIKCB'] = 'Nội trú'

# %%
before = frame_before[["MA_CSKCB","LOAIKCB", "MA_THE","SO_NGAY_DTRI","T_TONGCHI","T_BHTT"]].groupby(["MA_CSKCB","LOAIKCB"]).agg({'MA_THE':'count','SO_NGAY_DTRI':'sum','T_TONGCHI':'sum','T_BHTT':'sum'})

# %%
before['NGAY_DTRI_BQ'] = before["SO_NGAY_DTRI"] / before["MA_THE"]
before['CHIPHI_BQ'] = before["T_TONGCHI"] / before["MA_THE"]

# %%
before.head()
# Out:
#                              MA_THE  SO_NGAY_DTRI     T_TONGCHI        T_BHTT  \
# MA_CSKCB LOAIKCB
# 93001    Ngoại trú             3233             0  8.033277e+08  7.529879e+08
#          Nội trú               1011          7628  4.320002e+09  3.879393e+09
#          Điều trị Ngoại trú     115          2845  8.040100e+08  7.979278e+08
# 93002    Ngoại trú             4536             0  6.048547e+08  5.847370e+08
#          Nội trú                357          1942  5.846393e+08  5.226527e+08
#
#                              NGAY_DTRI_BQ     CHIPHI_BQ
# MA_CSKCB LOAIKCB
# 93001    Ngoại trú               0.000000  2.484775e+05
#          Nội trú                 7.545005  4.272999e+06
#          Điều trị Ngoại trú     24.739130  6.991391e+06
# 93002    Ngoại trú               0.000000  1.333454e+05
#          Nội trú                 5.439776  1.637645e+06

# %%
result = pd.merge(before, current,  how='left', left_on=['MA_CSKCB','LOAIKCB'], right_on = ['MA_CSKCB','LOAIKCB'], suffixes=('_KYTRUOC', '_KYHIENTAI'))

# %%
result = result.replace(np.nan, 0)
result['MA_THE_TANGGIAM'] = ((result['MA_THE_KYHIENTAI'] / result['MA_THE_KYTRUOC']) - 1)
result['TONG_CHI_TANGGIAM'] = ((result['T_TONGCHI_KYHIENTAI'] / result['T_TONGCHI_KYTRUOC']) - 1)
result['NGAY_DTRI_BQ_TANGGIAM'] = ((result['NGAY_DTRI_BQ_KYHIENTAI'] / result['NGAY_DTRI_BQ_KYTRUOC']) - 1)
result['CHIPHI_BQ_TANGGIAM'] = ((result['CHIPHI_BQ_KYHIENTAI'] / result['CHIPHI_BQ_KYTRUOC']) - 1)

# %%
total_result = result[['MA_THE_KYTRUOC','MA_THE_KYHIENTAI','MA_THE_TANGGIAM','T_TONGCHI_KYTRUOC','T_TONGCHI_KYHIENTAI','TONG_CHI_TANGGIAM','NGAY_DTRI_BQ_KYTRUOC','NGAY_DTRI_BQ_KYHIENTAI','NGAY_DTRI_BQ_TANGGIAM','CHIPHI_BQ_KYTRUOC','CHIPHI_BQ_KYHIENTAI','CHIPHI_BQ_TANGGIAM']]

# %%
total_result = total_result.replace(np.nan, 0)
total_result.style.format({
    'MA_THE_KYTRUOC': '{:,.2f}'.format,
    'MA_THE_KYHIENTAI': '{:,.2f}'.format,
    'T_TONGCHI_KYTRUOC': '{:,.2f}'.format,
    'T_TONGCHI_KYHIENTAI': '{:,.2f}'.format,
    'NGAY_DTRI_BQ_KYTRUOC': '{:,.2f}'.format,
    'NGAY_DTRI_BQ_KYHIENTAI': '{:,.2f}'.format,
    'CHIPHI_BQ_KYTRUOC': '{:,.2f}'.format,
    'CHIPHI_BQ_KYHIENTAI': '{:,.2f}'.format,
    'MA_THE_TANGGIAM': '{:,.2%}'.format,
    'TONG_CHI_TANGGIAM': '{:,.2%}'.format,
    'NGAY_DTRI_BQ_TANGGIAM': '{:,.2%}'.format,
    'CHIPHI_BQ_TANGGIAM': '{:,.2%}'.format})
# Out:
# <style  type="text/css" >
# ...

# %%
total_result.to_excel(r'D:\SOLIEU\SOLIEUPHANTICH\SOSANH\CHIPHIBQ.xlsx',merge_cells=False)

# %%
tong_luot = frame_current[["MA_CSKCB", "MA_THE"]].groupby(["MA_CSKCB"]).agg({'MA_THE':'count'})

# %%
so_luot_noi_tru = frame_current[(frame_current['MA_LOAIKCB'] == 3)]
tong_luot_noi_tru = so_luot_noi_tru[["MA_CSKCB", "MA_THE"]].groupby(["MA_CSKCB"]).agg({'MA_THE':'count'})

# %%
result_current = pd.merge(tong_luot, tong_luot_noi_tru,  how='left', left_on=['MA_CSKCB'], right_on = ['MA_CSKCB'], suffixes=('_TONGLUOTHIENTAI', '_NOITRUHIENTAI'))

# %%
result_current = result_current.replace(np.nan, 0)

# %%
tong_luot_before = frame_before[["MA_CSKCB", "MA_THE"]].groupby(["MA_CSKCB"]).agg({'MA_THE':'count'})

# %%
so_luot_noi_tru_before = frame_before[(frame_before['MA_LOAIKCB'] == 3)]
tong_luot_noi_tru_before = so_luot_noi_tru_before[["MA_CSKCB", "MA_THE"]].groupby(["MA_CSKCB"]).agg({'MA_THE':np.size})

# %%
result_before = pd.merge(tong_luot_before, tong_luot_noi_tru_before,  how='left', left_on=['MA_CSKCB'], right_on = ['MA_CSKCB'], suffixes=('_TONGLUOTKYTRUOC', '_NOITRUKYTRUOC'))

# %%
result = pd.merge(result_before, result_current,  how='left', left_on=['MA_CSKCB'], right_on = ['MA_CSKCB'])

# %%
result['TYLE_CHIDINH_NOITRU_KYTRUOC'] = result['MA_THE_NOITRUKYTRUOC'] / result['MA_THE_TONGLUOTKYTRUOC']
result['TYLE_CHIDINH_NOITRU_HIENTAI'] = result['MA_THE_NOITRUHIENTAI'] / result['MA_THE_TONGLUOTHIENTAI']
result['CHIPHI_CHIDINH_TANGGIAM'] = ((result['TYLE_CHIDINH_NOITRU_HIENTAI'] - result['TYLE_CHIDINH_NOITRU_KYTRUOC']))
total_result = result[["MA_THE_NOITRUKYTRUOC","MA_THE_TONGLUOTKYTRUOC","TYLE_CHIDINH_NOITRU_KYTRUOC","MA_THE_NOITRUHIENTAI","MA_THE_TONGLUOTHIENTAI","TYLE_CHIDINH_NOITRU_HIENTAI","CHIPHI_CHIDINH_TANGGIAM"]]

# %%
total_result = total_result.replace(np.nan, 0)
total_result = total_result.sort_values(by='TYLE_CHIDINH_NOITRU_HIENTAI', ascending=False)
total_result.to_excel(r'D:\SOLIEU\SOLIEUPHANTICH\SOSANH\TYLEDTRINOITRU.xlsx')

# %% [markdown]
# # Kiểm tra dữ liệu tăng giảm chi tiết từ SQLite

# %%
import sqlite3

# %%
# Dữ liệu tại năm hiện tại cần kiểm tra
con = sqlite3.connect(r'D:\DATACSDL\CSDL\2021\93_20210912_202101_202108_bao_cao_bhyt7980a.db')

# %%
# Cơ sở khám, chữa bệnh cần xem chi tiết dữ liệu
CSKCBKIEMTRA = '93001';

# %%
CHIPHITAICSKCB = (r' SELECT MA_CSKCB, KY_QT,'
                + ' Sum(CASE WHEN LOAI_BN = 1 THEN 1 ELSE 0  END) As "DKBD",'
                + ' Sum(CASE WHEN LOAI_BN = 2 THEN 1 ELSE 0  END) As "NOI_TINH",'
                + ' Sum(CASE WHEN LOAI_BN = 3 THEN 1 ELSE 0  END) As "NGOAI_TINH"'
                + ' from bhyt7980a' 
                + ' WHERE KY_QT BETWEEN 202101 and 202108 AND MA_CSKCB = ')

# %%
GROUPED = ' GROUP BY MA_CSKCB,KY_QT'

# %%
sql = CHIPHITAICSKCB + CSKCBKIEMTRA + GROUPED

# %%
# chi phí phát sinh tại 1 cskcb
CSCKBCANKIEMTRA = pd.read_sql_query(sql, con)
CSCKBCANKIEMTRA
# Out:
#   MA_CSKCB   KY_QT  DKBD  NOI_TINH  NGOAI_TINH
# 0    93001  202101  6258      1669         871
# 1    93001  202102  4691      1107         817
# 2    93001  202103  6399      1617        1064
# 3    93001  202104  5701      1464        1016
# 4    93001  202105  5554      1415         938
# 5    93001  202106  4900      1169         777
# 6    93001  202107  3255       756         348
# 7    93001  202108  2668       718         211

# %%
CHIPHITAICSKCB = (r' SELECT KY_QT,MA_DKBD,count(MA_THE)'             
                + ' from bhyt7980a' 
                + ' WHERE KY_QT BETWEEN 202101 and 202108 AND MA_CSKCB = ')

# %%
GROUPED = ' GROUP BY MA_DKBD,KY_QT'

# %%
sql = CHIPHITAICSKCB + CSKCBKIEMTRA + GROUPED

# %%
DANHSACHKHAMTAICSKCB =  pd.read_sql_query(sql, con)

# %%
DANHSACHKHAMTAICSKCB = DANHSACHKHAMTAICSKCB.sort_values(by='count(MA_THE)', ascending=False)
DANHSACHKHAMTAICSKCB
# Out:
#      KY_QT MA_DKBD  count(MA_THE)
# 3   202101   93003            907
# 5   202103   93003            821
# 4   202102   93003            759
# 10  202108   93003            707
# 6   202104   93003            672
# 8   202106   93003            635
# 7   202105   93003            574
# 9   202107   93003            196
# 32  202101   93094             33
# 34  202103   93094             24
# 35  202104   93094             23
# 39  202108   93094             17
# 33  202102   93094             14
# 36  202105   93094             14
# 42  202103   93098              8
# 47  202101   93101              8
# 38  202107   93094              6
# 13  202103   93004              6
# 44  202105   93098              6
# 50  202104   93101              6
# 37  202106   93094              6
# 41  202102   93098              5
# 48  202102   93101              5
# 11  202101   93004              5
# 14  202104   93004              5
# 12  202102   93004              4
# ...

# %%
df = pd.read_sql_query(r' SELECT MA_THE,MA_DKBD,HO_TEN,DIA_CHI'             
                + ' from bhyt7980a' 
                + ' WHERE KY_QT BETWEEN 202108 and 202108 AND MA_CSKCB = 93094 and MA_DKBD = 93003 and LOAI_BN = 1',con)
df[df["DIA_CHI"].str.contains("Tân Phú")]
# Out:
#               MA_THE MA_DKBD           HO_TEN  \
# 0    HN2939321571676   93003   DƯƠNG VĂN PHÚC
# 1    HN2939321571678   93003   VƯƠNG THỊ DIỆU
# 2    CN3939321544980   93003      BÙI VĂN TẠO
# 3    GB4939321575990   93003    TRẦN THỊ DIÊM
# 4    GB4939321535619   93003      LÊ VĂN ĐÚNG
# ..               ...     ...              ...
# 695  HS4939321600429   93003   LÊ PHÚC PHƯƠNG
# 697  TE1939321974522   93003      LÊ HỮU NHƠN
# 698  CH4935496007341   93003  TRẦN VĂN PHƯƠNG
# 699  CB2939321568748   93003   TRƯƠNG VĂN ĐÂY
# 700  GB4939321577217   93003   NGUYỄN THỊ XEM
#
#                                                DIA_CHI
# 0    ấp Tân Trị 1, Xã Tân Phú, Thị xã Long Mỹ, Tỉnh...
# 1    ấp Tân Trị 1, Xã Tân Phú, Thị xã Long Mỹ, Tỉnh...
# 2    ấp Tân Hòa, Xã Tân Phú, Thị xã Long Mỹ, Tỉnh H...
# 3    ấp tân trị 1, Xã Tân Phú Thị Xã Long Mỹ Tỉnh H...
# 4    ấp Tân Trị 1, Xã Tân Phú, Thị xã Long Mỹ, Tỉnh...
# ..                                                 ...
# ...

# %%
# Dữ liệu tại năm trước đó cần tham chiếu ngược
con_before = sqlite3.connect(r'D:\DATACSDL\CSDL\2020\93_20210110_202001_202012_bao_cao_bhyt7980a.db')

# %%
CHIPHITAICSKCB_Before = (r' SELECT MA_CSKCB, KY_QT,'
                + ' Sum(CASE WHEN LOAI_BN = 1 THEN 1 ELSE 0  END) As "DKBD",'
                + ' Sum(CASE WHEN LOAI_BN = 2 THEN 1 ELSE 0  END) As "NOI_TINH",'
                + ' Sum(CASE WHEN LOAI_BN = 3 THEN 1 ELSE 0  END) As "NGOAI_TINH"'
                + ' from bhyt7980a' 
                + ' WHERE KY_QT BETWEEN 202001 and 202008 AND MA_CSKCB = ')

# %%
GROUPED = ' GROUP BY MA_CSKCB,KY_QT'

# %%
sql = CHIPHITAICSKCB_Before + CSKCBKIEMTRA + GROUPED

# %%
# chi phí phát sinh tại 1 cskcb
CSCKBCANKIEMTRA_BEFORE= pd.read_sql_query(sql, con_before)
CSCKBCANKIEMTRA_BEFORE = CSCKBCANKIEMTRA_BEFORE.sort_values(by='KY_QT', ascending=False)
CSCKBCANKIEMTRA_BEFORE
# Out:
#   MA_CSKCB   KY_QT  DKBD  NOI_TINH  NGOAI_TINH
# 7    93001  202008  5174      1472         796
# 6    93001  202007  4061      2167        1008
# 5    93001  202006  3244      1702         950
# 4    93001  202005  2451      1530         953
# 3    93001  202004  2135      1173         724
# 2    93001  202003  2737      1516         870
# 1    93001  202002  3076      1583         904
# 0    93001  202001  3711      1905         982
